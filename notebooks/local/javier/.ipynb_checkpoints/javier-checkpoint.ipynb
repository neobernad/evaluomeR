# %% [markdown]
#  # Dataset

# %%
library("evaluomeR")

options(scipen=10)

# %% [markdown]
# # Dataset <a class="anchor" id="dataset"></a>

# %%
csv = read.csv2('ontoportal_agro_wide.csv',
                     header = T, sep = ",", na.strings = "NaN", stringsAsFactors = F)
data = as.data.frame(csv)

# %%
cols.num <- c(colnames(data)[-1])
data[cols.num] <- sapply(data[cols.num],as.numeric)
sapply(data, class)
# Out:
# Description      ANOnto       APWND       APWNN       APWNS      AROnto
# "character"   "numeric"   "numeric"   "numeric"   "numeric"   "numeric"
#     CBOOnto      CROnto     DITOnto         DxP     INROnto    LCOMOnto
#   "numeric"   "numeric"   "numeric"   "numeric"   "numeric"   "numeric"
#     NACOnto         NLR        NLRC     NOCOnto     NOMOnto         NxP
#   "numeric"   "numeric"   "numeric"   "numeric"   "numeric"   "numeric"
#       POnto      PROnto     RFCOnto      RROnto        SxAP         SxP
#   "numeric"   "numeric"   "numeric"   "numeric"   "numeric"   "numeric"
#      TMOnto     TMOnto2     WMCOnto    WMCOnto2
#   "numeric"   "numeric"   "numeric"   "numeric"

# %%
head(data)
# Out:
#   Description ANOnto    APWND     APWNN     APWNS AROnto     CBOOnto
# 1 AGFOOD      0.0000000 1.0000000 1.0000000 1       0.000000 4.000000
# 2 ASCOPAIN-T  0.0000000 1.0000000 1.0000000 1       0.000000 2.000000
# 3 ATOL        1.9919250 1.0000000 1.0000000 1       0.000000 1.036155
# 4 BCO         1.3121020 0.5866667 0.3733333 1     185.019100 1.058824
# 5 BFO         0.9722222 0.9166667 0.3750000 1       0.000000 1.000000
# 6 BIOREFINERY 0.0000000 1.0000000 1.0000000 1       4.992401 1.049612
#   CROnto      DITOnto DxP        ... POnto     PROnto    RFCOnto   RROnto
# 1 655.8000000  2      0.00000000 ... 0.0000000 0.0000000 0.8000000 1.0000000
# 2  29.0000000  2      0.00000000 ... 0.0000000 0.0000000 0.6666667 1.0000000
# 3   0.0000000 14      0.00000000 ... 1.0352740 0.0000000 1.0352740 1.0000000
# 4   0.1783439 11      0.83274020 ... 1.0382170 0.7249576 3.7515920 0.2750424
# 5   0.0000000  7      0.08333333 ... 0.9722222 0.0000000 0.9722222 1.0000000
# 6   1.1337390 10      0.00000000 ... 1.0121580 0.6726306 3.1428570 0.3273694
#   SxAP SxP       TMOnto     TMOnto2  WMCOnto  WMCOnto2
# 1 0    0.0000000 0.00000000 0.000000 1.000000 1.000000
# 2 0    0.0000000 0.00000000 0.000000 1.000000 1.000000
# 3 0    0.0000000 0.03231293 2.131579 8.805690 1.120460
# 4 0    0.1423488 0.05769231 2.000000 6.453704 1.268519
# 5 0    0.0000000 0.00000000 0.000000 4.904762 1.000000
# 6 0    0.0000000 0.02130898 2.571429 5.479401 1.037453

# %%
typeof(data[3, "APWNS"])
# Out:
# [1] "double"

# %% [markdown]
# # evaluomeR K analysis

# %%
seed = 100
k.range=c(3,10)
cbi = "kmeans"

# Stab
stab_range = stabilityRange(data=data, k.range=k.range, 
                            bs=100, seed=seed,
                            all_metrics=FALSE,
                            cbi=cbi)
stab = standardizeStabilityData(stab_range)
# Out:
# Data loaded.
# Number of rows: 41
# Number of columns: 28
#
#
# Processing metric: ANOnto(1)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: APWND(2)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 7
#
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 8
#
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 9
#
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 10
#
# 	Warning: Could not process data for k = 10
# Processing metric: APWNN(3)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 9
#
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 10
#
# 	Warning: Could not process data for k = 10
# Processing metric: APWNS(4)
# 	Calculation of k = 3
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 3
#
# 	Warning: Could not process data for k = 3
# 	Calculation of k = 4
# 	Warning: Could not process data for k = 4
# 	Calculation of k = 5
# 	Warning: Could not process data for k = 5
# 	Calculation of k = 6
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: AROnto(5)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: CBOOnto(6)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: CROnto(7)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: DITOnto(8)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"	Calculation of k = 9
# Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"	Calculation of k = 10
# Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Warning message:
# "did not converge in 100 iterations"Processing metric: DxP(9)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: INROnto(10)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: LCOMOnto(11)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NACOnto(12)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NLR(13)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 7
#
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 8
#
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 9
#
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 10
#
# 	Warning: Could not process data for k = 10
# Processing metric: NLRC(14)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 5
#
# 	Warning: Could not process data for k = 5
# 	Calculation of k = 6
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 6
#
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: NOCOnto(15)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NOMOnto(16)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NxP(17)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: POnto(18)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: PROnto(19)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: RFCOnto(20)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: RROnto(21)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: SxAP(22)
# 	Calculation of k = 3
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 3
#
# 	Warning: Could not process data for k = 3
# 	Calculation of k = 4
# 	Warning: Could not process data for k = 4
# 	Calculation of k = 5
# 	Warning: Could not process data for k = 5
# 	Calculation of k = 6
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: SxP(23)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 4
#
# 	Warning: Could not process data for k = 4
# 	Calculation of k = 5
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 5
#
# 	Warning: Could not process data for k = 5
# 	Calculation of k = 6
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 6
#
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 7
#
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 8
#
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 9
#
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: TMOnto(24)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: TMOnto2(25)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 6
#
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 7
#
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 8
#
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 9
#
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Error in kmeansruns(sdata, krange, runs = runs, criterion = criterion, : Cannot compute for k = 10
#
# 	Warning: Could not process data for k = 10
# Processing metric: WMCOnto(26)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: WMCOnto2(27)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
#
# Data loaded.
# Number of rows: 41
# Number of columns: 28
#
#
# Processing metric: ANOnto(1)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: APWND(2)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: APWNN(3)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: APWNS(4)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Warning: Could not process data for k = 4
# 	Calculation of k = 5
# 	Warning: Could not process data for k = 5
# 	Calculation of k = 6
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: AROnto(5)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: CBOOnto(6)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: CROnto(7)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: DITOnto(8)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: DxP(9)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: INROnto(10)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: LCOMOnto(11)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NACOnto(12)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NLR(13)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NLRC(14)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: NOCOnto(15)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NOMOnto(16)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NxP(17)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: POnto(18)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: PROnto(19)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: RFCOnto(20)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: RROnto(21)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: SxAP(22)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Warning: Could not process data for k = 4
# 	Calculation of k = 5
# 	Warning: Could not process data for k = 5
# 	Calculation of k = 6
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: SxP(23)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: TMOnto(24)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: TMOnto2(25)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: WMCOnto(26)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: WMCOnto2(27)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Error in `[[<-.data.frame`(`*tmp*`, newColname, value = c(0.704870131086381, : replacement has 25 rows, data has 27
# Traceback:
#
# 1. standardizeQualityData(qual_range)
# 2. `[[<-`(`*tmp*`, newColname, value = c(0.704870131086381, 0.870001808738741,
#  . 0.8202023734722, 0.681356384596321, 0.721331994982726, 0.935342901206103,
#  . 0.615916500947237, 0.74043578757667, 0.55322838909785, 0.629472215408008,
#  . 0.709676864534749, 0.717640662628958, 0.751463414634146, 0.511029820354188,
#  . 0.667057850270257, 0.710971606268752, 0.69824217493203, 0.666136885210039,
#  . 0.612863317138755, 0.666136898915016, 0.917866361023633, 0.681251091720023,
#  . 0.85280905578703, 0.626376969483055, 0.78116763047805))   # at line 612 of file C:/Users/Neo/workspace-r/evaluomeR/R/metricsAnalysis.R
# 3. `[[<-.data.frame`(`*tmp*`, newColname, value = c(0.704870131086381,
#  . 0.870001808738741, 0.8202023734722, 0.681356384596321, 0.721331994982726,
#  . 0.935342901206103, 0.615916500947237, 0.74043578757667, 0.55322838909785,
#  . 0.629472215408008, 0.709676864534749, 0.717640662628958, 0.751463414634146,
#  . 0.511029820354188, 0.667057850270257, 0.710971606268752, 0.69824217493203,
#  . 0.666136885210039, 0.612863317138755, 0.666136898915016, 0.917866361023633,
#  . 0.681251091720023, 0.85280905578703, 0.626376969483055, 0.78116763047805
#  . ))   # at line 612 of file C:/Users/Neo/workspace-r/evaluomeR/R/metricsAnalysis.R
# 4. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
# Qual
qual_range = qualityRange(data=data, k.range=k.range, 
                            all_metrics=FALSE, seed=seed,
                            cbi=cbi)
# Out:
# Data loaded.
# Number of rows: 41
# Number of columns: 28
#
#
# Processing metric: ANOnto(1)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: APWND(2)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: APWNN(3)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: APWNS(4)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Warning: Could not process data for k = 4
# 	Calculation of k = 5
# 	Warning: Could not process data for k = 5
# 	Calculation of k = 6
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: AROnto(5)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: CBOOnto(6)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: CROnto(7)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: DITOnto(8)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: DxP(9)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: INROnto(10)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: LCOMOnto(11)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NACOnto(12)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NLR(13)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NLRC(14)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: NOCOnto(15)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NOMOnto(16)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: NxP(17)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: POnto(18)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: PROnto(19)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: RFCOnto(20)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: RROnto(21)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: SxAP(22)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Warning: Could not process data for k = 4
# 	Calculation of k = 5
# 	Warning: Could not process data for k = 5
# 	Calculation of k = 6
# 	Warning: Could not process data for k = 6
# 	Calculation of k = 7
# 	Warning: Could not process data for k = 7
# 	Calculation of k = 8
# 	Warning: Could not process data for k = 8
# 	Calculation of k = 9
# 	Warning: Could not process data for k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: SxP(23)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# 	Warning: Could not process data for k = 10
# Processing metric: TMOnto(24)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: TMOnto2(25)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: WMCOnto(26)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# Processing metric: WMCOnto2(27)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10

# %%
qual = standardizeQualityData(qual_range)
# Out:
# Error in `[[<-.data.frame`(`*tmp*`, newColname, value = c(0.704870131086381, : replacement has 25 rows, data has 27
# Traceback:
#
# 1. standardizeQualityData(qual_range)
# 2. `[[<-`(`*tmp*`, newColname, value = c(0.704870131086381, 0.870001808738741,
#  . 0.8202023734722, 0.681356384596321, 0.721331994982726, 0.935342901206103,
#  . 0.615916500947237, 0.74043578757667, 0.55322838909785, 0.629472215408008,
#  . 0.709676864534749, 0.717640662628958, 0.751463414634146, 0.511029820354188,
#  . 0.667057850270257, 0.710971606268752, 0.69824217493203, 0.666136885210039,
#  . 0.612863317138755, 0.666136898915016, 0.917866361023633, 0.681251091720023,
#  . 0.85280905578703, 0.626376969483055, 0.78116763047805))   # at line 612 of file C:/Users/Neo/workspace-r/evaluomeR/R/metricsAnalysis.R
# 3. `[[<-.data.frame`(`*tmp*`, newColname, value = c(0.704870131086381,
#  . 0.870001808738741, 0.8202023734722, 0.681356384596321, 0.721331994982726,
#  . 0.935342901206103, 0.615916500947237, 0.74043578757667, 0.55322838909785,
#  . 0.629472215408008, 0.709676864534749, 0.717640662628958, 0.751463414634146,
#  . 0.511029820354188, 0.667057850270257, 0.710971606268752, 0.69824217493203,
#  . 0.666136885210039, 0.612863317138755, 0.666136898915016, 0.917866361023633,
#  . 0.681251091720023, 0.85280905578703, 0.626376969483055, 0.78116763047805
#  . ))   # at line 612 of file C:/Users/Neo/workspace-r/evaluomeR/R/metricsAnalysis.R
# 4. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
# K opt
k_opt = getOptimalKValue(stab_range, qual_range, k.range= k.range)
optimal_k = k_opt$Global_optimal_k
optimal_k_str = paste0("k_", optimal_k)
print(paste0("Optimal k: ", optimal_k))

# %%
print(paste0("W/ ", cbi))
stab
qual
print(paste0("Stab in k=", optimal_k,": ", stab[optimal_k_str]))
print(paste0("Qual in k=", optimal_k,": ", qual[optimal_k_str]))
# Out:
# [1] "W/ kmeans"
#             k_3       k_4      k_5       k_6       k_7       k_8
# all_metrics 0.7095172 0.752932 0.7906296 0.6669827 0.6719397 0.6983423
#             k_9       k_10
# all_metrics 0.6858506 0.7107412
#             k_3       k_4      k_5       k_6       k_7       k_8
# all_metrics 0.9088487 0.839488 0.7406826 0.3183344 0.3821698 0.3397723
#             k_9       k_10
# all_metrics 0.3584338 0.3810308
# [1] "Stab in k=5: 0.790629612370848"
# [1] "Qual in k=5: 0.740682621318558"

# %% [markdown]
# # Clusters

# %%
individuals_per_cluster = function(qualityResult) {
  qual_df = as.data.frame(assay(qualityResult))


  cluster_pos_str = as.character(unlist(qual_df["Cluster_position"]))
  cluster_labels_str = as.character(unlist(qual_df["Cluster_labels"]))

  cluster_pos = as.list(strsplit(cluster_pos_str, ",")[[1]])
  cluster_labels = as.list(strsplit(cluster_labels_str, ",")[[1]])

  individuals_in_cluster = as.data.frame(cbind(cluster_labels, cluster_pos))
  colnames(individuals_in_cluster) = c("Individual", "InCluster")

  return(individuals_in_cluster)
}

# %%
qual_cbi = qualityRange(data=data, k.range=k.range, 
                            all_metrics=TRUE, seed=seed,
                            cbi=cbi)
cluster_individuals = individuals_per_cluster(assay(qual_cbi[optimal_k_str]))
print(paste0("CBI: ", cbi, " - k: ", optimal_k))
standardizeQualityData(qual_cbi)
for (cluster_i in 1:optimal_k) {
    ind_in_cluster = paste(unlist(cluster_individuals[cluster_individuals$InCluster == cluster_i, ]["Individual"]), collapse = ",")
    print(paste("Cluster", cluster_i, ":", ind_in_cluster))
    print("---")
}
# Out:
# Data loaded.
# Number of rows: 41
# Number of columns: 28
#
#
# Processing all metrics, 'merge', in dataframe (27)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# 	Calculation of k = 7
# 	Calculation of k = 8
# 	Calculation of k = 9
# 	Calculation of k = 10
# [1] "CBI: kmeans - k: 5"
#             k_3       k_4      k_5       k_6       k_7       k_8
# all_metrics 0.9088487 0.839488 0.7406826 0.3183344 0.3821698 0.3397723
#             k_9       k_10
# all_metrics 0.3584338 0.3810308
# [1] "Cluster 1 : ASCOPAIN-T,ATOL,BFO,BIOREFINERY,BIPON,BOHLMANN,C3PO,CASO,CDAO,DSW,EDAM,EFO,EOL,FALDO,GECO,GFVO,GO,IRRIG,OBOE,ONTOBIOTOPE,PEAO,PO,PPDO,PPO,PSO,SAREF,SAREF4ENVI,SO,SOSA,SSN,UO,VT,WHEATPHENOTYPE"
# [1] "---"
# [1] "Cluster 2 : BCO,CDNO,RO,SIO"
# [1] "---"
# [1] "Cluster 3 : INRAETHES"
# [1] "---"
# [1] "Cluster 4 : AGFOOD,CVO"
# [1] "---"
# [1] "Cluster 5 : FOODEX2"
# [1] "---"

# %% [markdown]
# # Clest <a class="anchor" id="clest"></a>

# %%
#top_golub_copy = top_golub
#top_golub[-1]

# %%
# -- Clest
#golub_clest = Clest(as.matrix(top_golub_copy[-1]), maxK = 6, alpha=0, B=3, B0=10, beta = 0.01, nstart=100,pca=FALSE,L1=3,silent=TRUE);

# %%
#names(golub_clest)
#golub_clest$observedCERs
#golub_clest$K

# %%
#?Clest

# %% [markdown]
# # PCA <a class="anchor" id="pca"></a>

# %%
#PCA
print(length(cluster_individuals$InCluster))
print(nrow(top_golub))
top_golub["inCluster"] = as.numeric(cluster_individuals$InCluster)
unique(cluster_individuals$InCluster)
# Out:
# [1] 41
# Error in nrow(top_golub): objeto 'top_golub' no encontrado
# Traceback:
#
# 1. print(nrow(top_golub))
# 2. nrow(top_golub)

# %%
pca_matrix = top_golub %>% select(-Description, -inCluster)
head(pca_matrix)

# %%
pca_result <- prcomp(pca_matrix, scale. = TRUE)

# %%
pca_df <- data.frame(pca_result$x)
pca_df$Cluster <- as.factor(top_golub$inCluster)
pca_df$Individual <- top_golub$Description

# Plot PCA results

ggplot2::ggplot(pca_df, ggplot2::aes(x = PC1, y = PC2, color = Cluster, label = Individual)) +
  ggplot2::geom_point(size = 3) +
  ggplot2::geom_text(vjust = 1, hjust = 1) +
  ggplot2::labs(title = "PCA of Features",
       x = "Principal Component 1",
       y = "Principal Component 2") +
  ggplot2::theme_minimal()

# %% [markdown]
# # Sensitivity <a class="anchor" id="sensitivity"></a>

# %%
library("MLmetrics")

# %%
top_golub["Class"] = as.data.frame(leukemia)["Class"]
head(top_golub)[, c("Description", "Class")]

# %%
# Define levels and their corresponding numbers
# Order is important
# kmeans k = 4
#level_mapping <- c("M" = 1, "T" = 2, "MM" = 3, "B" = 4)
# clara k = 3
level_mapping <- c("B" = 1, "T" = 2, "M" = 3)

# %%
map_strings_to_numbers <- function(strings) {
  factorized <- factor(strings, levels = names(level_mapping))
  as.numeric(factorized)
}
top_golub["Class_n"] = lapply(top_golub["Class"], map_strings_to_numbers)
top_golub[, c("Description", "Class", "Class_n")]

# %%
# Getting a vector of clusters
actual = as.factor(as.vector(unlist(top_golub["Class_n"])))
predicted <- factor(as.vector(unlist(top_golub["inCluster"])))

print("actual")
actual
print("predicted")
predicted

# %%
sens <- Sensitivity(y_pred = predicted, y_true = actual)
sens = format(round(sens*100, 2), nsmall = 2)
print(paste0("Sensitivity: ", sens, "%"))

# %% [markdown]
# # CER <a class="anchor" id="cer"></a>

# %%
cer <- CER(predicted, actual)
cer = format(round(cer*100, 2), nsmall = 2)
print(paste0("CER: ", cer, "%"))
