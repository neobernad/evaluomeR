# %% [markdown]
# # evaluomeR - optimal $k$ analysis

# %%
library("evaluomeR")
library("ISLR") 

options(scipen=10)

# %% [markdown]
# # Table of contents
# * [Dataset](#dataset)
# * [Analysis per metric](#single)
#     * [Stability](#single_stab)
#     * [Quality](#single_qual)
#     * [Optimal K value](#single_optimal)
# * [Multidimensional optimal k analysis](#all)
#     * [Stability](#all_stab)
#     * [Quality](#all_qual)
#     * [Optimal K value](#all_optimal)

# %% [markdown]
# # Dataset <a class="anchor" id="dataset"></a>
# We are going to use the NCI60 dataset, actually a subsample of the first 500 columns for testing purposes.

# %%
seed = 13606
set.seed(seed)

nci60 = as.data.frame(NCI60$data)
# Creating a Description column
nci60["labels"] = rownames(nci60)
nci60 = nci60[ , c("labels", names(nci60)[names(nci60) != "labels"])]
nci60["labels"] = NCI60$labs
colnames(nci60)[colnames(nci60) == 'labels'] <- 'Description'
nci60 = nci60[1:500]
head(nci60)
# Out:
#    Description 1        2         3         4         5         6
# V1 CNS         0.300000  1.180000  0.550000  1.140000 -0.265000 -7.000000e-02
# V2 CNS         0.679961  1.289961  0.169961  0.379961  0.464961  5.799610e-01
# V3 CNS         0.940000 -0.040000 -0.170000 -0.040000 -0.605000  0.000000e+00
# V4 RENAL       0.280000 -0.310000  0.680000 -0.810000  0.625000 -1.387779e-17
# V5 BREAST      0.485000 -0.465000  0.395000  0.905000  0.200000 -5.000000e-03
# V6 CNS         0.310000 -0.030000 -0.100000 -0.460000 -0.205000 -5.400000e-01
#    7         8         9           ... 490       491       492       493
# V1  0.350000 -0.315000 -0.45000000 ... -0.430000 -0.035000  0.100000 -0.285000
# V2  0.699961  0.724961 -0.04003899 ... -0.330039 -0.605039 -0.580039 -0.985039
# V3  0.090000  0.645000  0.43000000 ...  0.230000 -0.775000 -0.850000 -0.665000
# V4  0.170000  0.245000  0.02000000 ... -0.180000  0.385000 -0.680000 -0.115000
# V5  0.085000  0.110000  0.23500000 ... -0.195000 -0.150000 -0.755000 -0.720000
# V6 -0.640000 -0.585000 -0.77000000 ... -0.670000 -0.515000 -0.140000 -0.215000
#    494       495         496       497         498         499
# V1 -0.140000  0.01999023  0.370000 -0.38000000 -0.37250000 -0.3200195
# V2 -0.550039  0.41995120  0.129961 -0.09003899  0.03746101  0.0000000
# V3 -0.860000  0.23999020 -1.190000 -0.84000000 -0.51250000 -0.8900195
# V4 -0.660000  0.12999020 -0.600000 -0.52000000 -0.32250000 -0.2600195
# V5 -0.355000 -1.31500977 -0.975000 -0.81500000 -0.67750000 -1.3450195
# V6 -0.140000  0.30999020 -0.060000 -0.57000000 -0.54250000 -0.5500195

# %% [markdown]
# # Analysis per metric <a class="anchor" id="single"></a>
# This demonstrates how to conduct an optimal $k$ analysis for each metric or feature in an input dataset. In this instance, we iterate over the range of $k \in [3,6]$. To avoid binary classifications, we exclude $k=2$. The CBI *kmeans* serves as the default clustering method.

# %%
k.range=c(3,6)
cbi="kmeans"

# %% [markdown]
# ### Stability <a class="anchor" id="single_stab"></a>

# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 402(402)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 403(403)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 404(404)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 405(405)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 406(406)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 407(407)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 408(408)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 409(409)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 410(410)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 411(411)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 412(412)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 413(413)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 414(414)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 415(415)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 416(416)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 417(417)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 418(418)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 419(419)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 420(420)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 421(421)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 422(422)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 423(423)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 424(424)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 425(425)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 426(426)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 427(427)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 428(428)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 429(429)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 430(430)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 431(431)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 432(432)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 433(433)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 434(434)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 435(435)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 436(436)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 437(437)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 438(438)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 439(439)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 440(440)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 441(441)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 442(442)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 443(443)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 444(444)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 445(445)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 446(446)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 447(447)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 448(448)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 449(449)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 450(450)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 451(451)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 452(452)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 453(453)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 454(454)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 455(455)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 456(456)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 457(457)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 458(458)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 459(459)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 460(460)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 461(461)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 462(462)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 463(463)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 464(464)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 465(465)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 466(466)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 467(467)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 468(468)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 469(469)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 470(470)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 471(471)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 472(472)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 473(473)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 474(474)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 475(475)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 476(476)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 477(477)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 478(478)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 479(479)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 480(480)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 481(481)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 482(482)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 483(483)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 484(484)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 485(485)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 486(486)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 487(487)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 488(488)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 489(489)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 490(490)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 491(491)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 492(492)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 493(493)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 494(494)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 495(495)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 496(496)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 497(497)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 498(498)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
# Processing metric: 499(499)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6

# %% [markdown]
# Qualities for each metric and for each $k$ value can be seen in the `qual` dataframe:

# %%
head(qual, 10)
# Out:
#     k_3       k_4       k_5       k_6
# 1   0.5695830 0.5037385 0.5475433 0.5743570
# 10  0.5541852 0.5183693 0.5928258 0.5828366
# 100 0.6277726 0.6035017 0.6088439 0.5825842
# 101 0.5540026 0.5707742 0.5448087 0.5240356
# 102 0.5577970 0.5500509 0.5498305 0.5698660
# 103 0.5739099 0.5486029 0.5918741 0.5635921
# 104 0.5310612 0.4930869 0.5700545 0.6139769
# 105 0.5604474 0.5675506 0.5642461 0.4991574
# 106 0.5659673 0.5014090 0.5079362 0.4878480
# 107 0.5341215 0.5960120 0.6206004 0.6312832

# %% [markdown]
# ### Optimal K value <a class="anchor" id="single_optimal"></a>
# In this Section we show how to compute the optimal $k$ value of a dataset **per metric**.

# %%
k_opt = getOptimalKValue(stab_range, qual_range, k.range= k.range)
optimal_k = as.numeric(k_opt$Global_optimal_k)
# Out:
# Processing metric: 1
#
# 	Both Ks have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 2
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 3
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 4
#
# 	Stability k '3' is stable but quality k '5' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 5
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 6
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 7
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 8
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 9
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 10
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 11
#
# 	Stability k '4' is stable but quality k '6' is not
#
# 	Using '4' since it provides higher stability
#
# Processing metric: 12
#
# 	Both Ks have a stable classification: '5', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 13
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 14
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 15
#
# 	Both Ks have a stable classification: '4', '3'
#
# 	Using '3' since it provides higher silhouette width
#
# Processing metric: 16
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 17
#
# 	Both Ks have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 18
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 19
#
# 	Both Ks have a stable classification: '3', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 20
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 21
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 22
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 23
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 24
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 25
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 26
#
# 	Both Ks have a stable classification: '5', '3'
#
# 	Using '3' since it provides higher silhouette width
#
# Processing metric: 27
#
# 	Both Ks do not have a stable classification: '5', '3'
#
# 	Using '3' since it provides higher silhouette width
#
# Processing metric: 28
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 29
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 30
#
# 	Both Ks do not have a stable classification: '6', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 31
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 32
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 33
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 34
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 35
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 36
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 37
#
# 	Both Ks do not have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 38
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 39
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 40
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 41
#
# 	Stability k '3' is stable but quality k '5' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 42
#
# 	Stability k '5' is stable but quality k '6' is not
#
# 	Using '5' since it provides higher stability
#
# Processing metric: 43
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 44
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 45
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 46
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 47
#
# 	Stability k '5' is stable but quality k '6' is not
#
# 	Using '5' since it provides higher stability
#
# Processing metric: 48
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 49
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 50
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 51
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 52
#
# 	Both Ks do not have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 53
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 54
#
# 	Both Ks have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 55
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 56
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 57
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 58
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 59
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 60
#
# 	Both Ks have a stable classification: '3', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 61
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 62
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 63
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 64
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 65
#
# 	Both Ks do not have a stable classification: '5', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 66
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 67
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 68
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 69
#
# 	Both Ks have a stable classification: '3', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 70
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 71
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 72
#
# 	Both Ks have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 73
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 74
#
# 	Stability k '4' is stable but quality k '5' is not
#
# 	Using '4' since it provides higher stability
#
# Processing metric: 75
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 76
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 77
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 78
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric:
a stable classification: '5', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 381
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 382
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 383
#
# 	Both Ks have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 384
#
# 	Stability k '5' is stable but quality k '6' is not
#
# 	Using '5' since it provides higher stability
#
# Processing metric: 385
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 386
#
# 	Both Ks have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 387
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 388
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 389
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 390
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 391
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 392
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 393
#
# 	Both Ks have a stable classification: '4', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 394
#
# 	Both Ks do not have a stable classification: '5', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 395
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 396
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 397
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 398
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 399
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 400
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 401
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 402
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 403
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 404
#
# 	Stability k '3' is stable but quality k '5' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 405
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 406
#
# 	Both Ks have a stable classification: '3', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 407
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 408
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 409
#
# 	Both Ks have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 410
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 411
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 412
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 413
#
# 	Both Ks have a stable classification: '4', '3'
#
# 	Using '3' since it provides higher silhouette width
#
# Processing metric: 414
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 415
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 416
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 417
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 418
#
# 	Stability k '5' is stable but quality k '6' is not
#
# 	Using '5' since it provides higher stability
#
# Processing metric: 419
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 420
#
# 	Both Ks do not have a stable classification: '5', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 421
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 422
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 423
#
# 	Both Ks do not have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 424
#
# 	Both Ks do not have a stable classification: '6', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 425
#
# 	Stability k '4' is stable but quality k '5' is not
#
# 	Using '4' since it provides higher stability
#
# Processing metric: 426
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 427
#
# 	Stability k '3' is stable but quality k '4' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 428
#
# 	Both Ks have a stable classification: '3', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 429
#
# 	Both Ks have a stable classification: '5', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 430
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 431
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 432
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 433
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 434
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 435
#
# 	Both Ks have a stable classification: '3', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 436
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 437
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 438
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 439
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 440
#
# 	Both Ks have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 441
#
# 	Both Ks have a stable classification: '5', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 442
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 443
#
# 	Stability k '5' is stable but quality k '6' is not
#
# 	Using '5' since it provides higher stability
#
# Processing metric: 444
#
# 	Both Ks do not have a stable classification: '6', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 445
#
# 	Both Ks do not have a stable classification: '6', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 446
#
# 	Stability k '5' is stable but quality k '6' is not
#
# 	Using '5' since it provides higher stability
#
# Processing metric: 447
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 448
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 449
#
# 	Both Ks have a stable classification: '3', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 450
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 451
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 452
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 453
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 454
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 455
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 456
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 457
#
# 	Stability k '3' is stable but quality k '5' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 458
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 459
#
# 	Both Ks have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 460
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 461
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 462
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 463
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 464
#
# 	Stability k '4' is stable but quality k '6' is not
#
# 	Using '4' since it provides higher stability
#
# Processing metric: 465
#
# 	Stability k '3' is stable but quality k '5' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 466
#
# 	Both Ks have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 467
#
# 	Both Ks have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 468
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 469
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 470
#
# 	Stability k '3' is stable but quality k '5' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 471
#
# 	Maximum stability and quality values matches the same K value: '5'
#
# Processing metric: 472
#
# 	Both Ks have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 473
#
# 	Both Ks do not have a stable classification: '3', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 474
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 475
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 476
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 477
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 478
#
# 	Maximum stability and quality values matches the same K value: '4'
#
# Processing metric: 479
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 480
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 481
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 482
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 483
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 484
#
# 	Both Ks have a stable classification: '5', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 485
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 486
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 487
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 488
#
# 	Both Ks do not have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 489
#
# 	Both Ks have a stable classification: '3', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 490
#
# 	Both Ks do not have a stable classification: '5', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 491
#
# 	Both Ks have a stable classification: '5', '4'
#
# 	Using '4' since it provides higher silhouette width
#
# Processing metric: 492
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 493
#
# 	Both Ks have a stable classification: '3', '5'
#
# 	Using '5' since it provides higher silhouette width
#
# Processing metric: 494
#
# 	Maximum stability and quality values matches the same K value: '3'
#
# Processing metric: 495
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 496
#
# 	Stability k '3' is stable but quality k '6' is not
#
# 	Using '3' since it provides higher stability
#
# Processing metric: 497
#
# 	Both Ks have a stable classification: '4', '6'
#
# 	Using '6' since it provides higher silhouette width
#
# Processing metric: 498
#
# 	Maximum stability and quality values matches the same K value: '6'
#
# Processing metric: 499
#
# 	Maximum stability and quality values matches the same K value: '4'

# %% [markdown]
# In the following table, we show the $k$ where the metric was most stable in `Stability_max_k` column, in what $k$ we had the highest goodness (quality) in `Quality_max_k` and what is the decision of `evaluomeR` to compute the overall $k$ value of the metric in `Global_optimal_k`.

# %%
head(k_opt, 10)
# Out:
#    Metric Stability_max_k Stability_max_k_stab Stability_max_k_qual
# 1  1      3               0.7978412            0.5695830
# 2  2      3               0.7903263            0.5609821
# 3  3      3               0.7816762            0.5523531
# 4  4      3               0.7888597            0.6147062
# 5  5      5               0.8061986            0.5616904
# 6  6      3               0.9137646            0.6170207
# 7  7      3               0.9116126            0.5920057
# 8  8      3               0.9448024            0.5850644
# 9  9      3               0.9576668            0.6143360
# 10 10     3               0.8310416            0.5541852
#    Quality_max_k Quality_max_k_stab Quality_max_k_qual Global_optimal_k
# 1  6             0.7626800          0.5743570          6
# 2  6             0.6903602          0.6005832          3
# 3  3             0.7816762          0.5523531          3
# 4  5             0.6697399          0.6149489          3
# 5  5             0.8061986          0.5616904          5
# 6  3             0.9137646          0.6170207          3
# 7  3             0.9116126          0.5920057          3
# 8  3             0.9448024          0.5850644          3
# 9  6             0.7434382          0.6282880          3
# 10 5             0.7643663          0.5928258          5

# %% [markdown]
# # Multidimensional optimal k analysis <a class="anchor" id="all"></a>
# This outlines the process of determining an optimal $k$ value for the entire dataset. In this scenario, we calculate the optimal $k$ across the dataset as a whole. Once again we consider a $k$ range such as $k \in [3, 6]$, excluding $k = 2$ to avoid binary classifications. The CBI *kmeans* method is utilized as the default clustering algorithm.

# %% [markdown]
# ### Stability <a class="anchor" id="all_stab"></a>
# Here we set the parameter `all_metrics=TRUE` in order to consider the stability of all the metrics as a whole.

# %%
stab_range = stabilityRange(data=nci60, k.range=k.range,
                            all_metrics=TRUE,
                            bs=100,
                            cbi=cbi)
stab = standardizeStabilityData(stab_range)
stab
# Out:
# Data loaded.
# Number of rows: 64
# Number of columns: 500
#
#
# Processing all metrics, 'merge', in dataframe (499)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
#             k_3       k_4       k_5       k_6
# all_metrics 0.6342906 0.6680511 0.5301713 0.5237286

# %% [markdown]
# In the table above, not all individual metrics are displayed; instead, a combined variable named `all_metrics` wchih represents the overall stability of metrics across the dataset.

# %% [markdown]
# ### Quality <a class="anchor" id="all_qual"></a>
# Similarly as in the [Stability](#all_stab) Section, setting up the parameter `all_metrics=TRUE` is needed to consider all the metrics.

# %%
qual_range = qualityRange(data=nci60, k.range=k.range,
                          all_metrics=TRUE,
                          cbi=cbi)
qual = standardizeQualityData(qual_range)
qual
# Out:
# Data loaded.
# Number of rows: 64
# Number of columns: 500
#
#
# Processing all metrics, 'merge', in dataframe (499)
# 	Calculation of k = 3
# 	Calculation of k = 4
# 	Calculation of k = 5
# 	Calculation of k = 6
#             k_3       k_4       k_5       k_6
# all_metrics 0.1181279 0.1059742 0.1063796 0.08479927

# %% [markdown]
# ### Optimal K value <a class="anchor" id="all_optimal"></a>
# In this Section we show how to compute the optimal $k$ value considering all the metrics from **the whole dataset**.

# %%
k_opt = getOptimalKValue(stab_range, qual_range, k.range= k.range)
optimal_k = as.numeric(k_opt$Global_optimal_k)
k_opt
# Out:
# Processing metric: all_metrics
#
# 	Both Ks do not have a stable classification: '4', '3'
#
# 	Using '3' since it provides higher silhouette width
#   Metric      Stability_max_k Stability_max_k_stab Stability_max_k_qual
# 1 all_metrics 4               0.6680511            0.1059742
#   Quality_max_k Quality_max_k_stab Quality_max_k_qual Global_optimal_k
# 1 3             0.6342906          0.1181279          3

# %% [markdown]
# In the previous table, according to the column `Global_optimal_k`, `evaluomeR` considered that the optimal $k$ value for the given dataset is $k=3$.
